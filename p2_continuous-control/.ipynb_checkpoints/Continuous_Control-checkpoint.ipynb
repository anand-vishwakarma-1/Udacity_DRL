# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.10699999760836362

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Policy Model."""

    def __init__(self, state_size, action_size, seed, n_fc1=128, n_fc2=128):
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcLayer1 = nn.Linear(state_size, n_fc1)
        self.fcLayer2 = nn.Linear(n_fc1, n_fc2)
        self.fcLayer3 = nn.Linear(n_fc2, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcLayer1.weight.data.uniform_(*hidden_init(self.fcLayer1))
        self.fcLayer2.weight.data.uniform_(*hidden_init(self.fcLayer2))
        self.fcLayer3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        x = F.relu(self.fcLayer1(state))
        x = F.relu(self.fcLayer2(x))
        return F.tanh(self.fcLayer3(x))

# %%
class Critic(nn.Module):
    """Value Model."""

    def __init__(self, state_size, action_size, seed, n_fc1=128, n_fc2=128):
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcLayer1 = nn.Linear(state_size, n_fc1)
        self.fcLayer2 = nn.Linear(n_fc1+action_size, n_fc2)
        self.fcLayer3 = nn.Linear(n_fc2, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcLayer1.weight.data.uniform_(*hidden_init(self.fcLayer1))
        self.fcLayer2.weight.data.uniform_(*hidden_init(self.fcLayer2))
        self.fcLayer3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        xs = F.relu(self.fcLayer1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fcLayer2(x))
        return self.fcLayer3(x)

# %%
import random
import copy
import time

import torch.optim as optim

BUFFER_SIZE = int(1e6)
BATCH_SIZE = 256
GAMMA = 0.99
TAU = 1e-3
LR_ACTOR = 1e-3
LR_CRITIC = 1e-3
WEIGHT_DECAY = 0
EPSILON = 1.0
EPSILON_DECAY = 1e-6
LEARNING_PERIOD = 20  
UPDATE_FACTOR   = 10

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Agent():
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, random_seed):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        self.epsilon = EPSILON

        # Actor Networks
        self.actor_local = Actor(state_size, action_size, random_seed).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=LR_ACTOR)

        # Critic Networks
        self.critic_local = Critic(state_size, action_size, random_seed).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=LR_CRITIC, weight_decay=WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = Experience(action_size, BUFFER_SIZE, BATCH_SIZE, random_seed)

        # Make sure target is with the same weight as the source
        self.copy(self.actor_target, self.actor_local)
        self.copy(self.critic_target, self.critic_local)

    def step(self, states, actions, rewards, next_states, dones, timestep):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
            self.memory.add(state, action, reward, next_state, done)

        # Learn, if enough samples are available in memory
        if len(self.memory) > BATCH_SIZE and timestep % LEARNING_PERIOD == 0:
            for _ in range(UPDATE_FACTOR):
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""

        state = torch.from_numpy(state).float().to(device)

        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()

        if add_noise:
            action += self.epsilon * self.noise.sample()

        return action

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples."""
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)

        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)

        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic_local.parameters(), 1)
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()

        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.update(self.critic_local, self.critic_target, TAU)
        self.update(self.actor_local, self.actor_target, TAU)

        # ---------------------------- update noise ---------------------------- #
        self.epsilon -= EPSILON_DECAY
        self.noise.reset()

    def update(self, local_model, target_model, tau):
        """update model parameters."""
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

    def copy(self, target, source):
        for target_param, param in zip(target.parameters(), source.parameters()):
            target_param.data.copy_(param.data)

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        self.state = copy.copy(self.mu)

    def sample(self):
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

# %%
from collections import namedtuple, deque

class Experience:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
def ddpg(n_episodes=1000, print_every=10):
    scores_deque = deque(maxlen=100)
    scores_global = []
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores = np.zeros(num_agents)                          # initialize the score (for each agent)
        agent.reset()
        score_average = 0

        for timestep in range(2000):
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = env_info.local_done
            agent.step(states, actions, rewards, next_states, dones, timestep)
            states = next_states
            scores += rewards
            if np.any(dones):
                break
        
        score = np.mean(scores)
        scores_deque.append(score)
        score_average = np.mean(scores_deque)
        scores_global.append(score)
        
        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f} '\
              .format(i_episode, score, np.max(scores), np.min(scores)))
        
        if i_episode % print_every == 0 or (len(scores_deque) == 100 and np.mean(scores_deque) >= 30) :
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {}\tAverage Score: {:.2f}, Time: {:02}:{:02}:{:02} *** '\
                  .format(i_episode, np.mean(scores_deque), s//3600, s%3600//60, s%60))  
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 30:  
            print('Environment solved !')
            break
            
    return scores_global

# %%
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8)
scores = ddpg()
# Out:
# Episode: 1, Score: 0.03, Max: 0.25, Min: 0.00
# Episode: 2, Score: 0.73, Max: 1.42, Min: 0.00
# Episode: 3, Score: 0.65, Max: 1.32, Min: 0.06
# Episode: 4, Score: 0.96, Max: 1.86, Min: 0.27
# Episode: 5, Score: 0.79, Max: 1.79, Min: 0.15
# Episode: 6, Score: 0.66, Max: 1.46, Min: 0.00
# Episode: 7, Score: 0.89, Max: 2.12, Min: 0.17
# Episode: 8, Score: 0.66, Max: 1.58, Min: 0.23
# Episode: 9, Score: 0.83, Max: 1.76, Min: 0.14
# Episode: 10, Score: 1.12, Max: 2.69, Min: 0.37
# *** Episode 10	Average Score: 0.73, Time: 00:02:01 ***
# Episode: 11, Score: 1.15, Max: 1.96, Min: 0.29
# Episode: 12, Score: 0.94, Max: 2.25, Min: 0.00
# Episode: 13, Score: 1.02, Max: 2.70, Min: 0.35
# Episode: 14, Score: 1.51, Max: 3.05, Min: 0.37
# Episode: 15, Score: 1.28, Max: 2.21, Min: 0.49
# Episode: 16, Score: 1.16, Max: 2.04, Min: 0.38
# Episode: 17, Score: 1.35, Max: 2.93, Min: 0.10
# Episode: 18, Score: 1.14, Max: 2.01, Min: 0.11
# Episode: 19, Score: 0.96, Max: 2.57, Min: 0.10
# Episode: 20, Score: 1.60, Max: 2.96, Min: 0.55
# *** Episode 20	Average Score: 0.97, Time: 00:04:54 ***
# Episode: 21, Score: 1.44, Max: 2.34, Min: 0.68
# Episode: 22, Score: 1.73, Max: 3.43, Min: 0.81
# Episode: 23, Score: 1.85, Max: 3.01, Min: 0.40
# Episode: 24, Score: 1.68, Max: 2.95, Min: 0.39
# Episode: 25, Score: 1.53, Max: 2.55, Min: 0.17
# Episode: 26, Score: 1.62, Max: 2.55, Min: 0.84
# Episode: 27, Score: 1.66, Max: 3.35, Min: 0.37
# Episode: 28, Score: 2.23, Max: 3.11, Min: 0.99
# Episode: 29, Score: 1.98, Max: 3.73, Min: 0.97
# Episode: 30, Score: 1.92, Max: 3.30, Min: 0.64
# *** Episode 30	Average Score: 1.24, Time: 00:08:38 ***
# Episode: 31, Score: 1.55, Max: 2.28, Min: 0.47
# Episode: 32, Score: 1.74, Max: 3.95, Min: 0.70
# Episode: 33, Score: 1.84, Max: 3.40, Min: 0.86
# Episode: 34, Score: 2.31, Max: 5.02, Min: 0.78
# Episode: 35, Score: 1.75, Max: 3.08, Min: 0.80
# Episode: 36, Score: 2.00, Max: 3.47, Min: 0.70
# Episode: 37, Score: 2.15, Max: 3.40, Min: 0.59
# Episode: 38, Score: 2.36, Max: 4.71, Min: 0.81
# Episode: 39, Score: 1.90, Max: 3.02, Min: 0.42
# Episode: 40, Score: 1.95, Max: 3.83, Min: 1.01
# *** Episode 40	Average Score: 1.42, Time: 00:13:08 ***
# Episode: 41, Score: 1.76, Max: 3.39, Min: 0.77
# Episode: 42, Score: 2.32, Max: 4.67, Min: 0.96
# Episode: 43, Score: 1.90, Max: 3.60, Min: 0.49
# Episode: 44, Score: 2.09, Max: 5.19, Min: 0.61
# Episode: 45, Score: 2.30, Max: 3.86, Min: 0.98
# Episode: 46, Score: 2.87, Max: 4.76, Min: 1.19
# Episode: 47, Score: 3.09, Max: 5.71, Min: 1.96
# Episode: 48, Score: 2.85, Max: 4.62, Min: 0.76
# Episode: 49, Score: 2.85, Max: 4.62, Min: 0.83
# Episode: 50, Score: 3.03, Max: 4.36, Min: 1.90
# *** Episode 50	Average Score: 1.63, Time: 00:18:21 ***
# Episode: 51, Score: 3.23, Max: 5.43, Min: 1.48
# Episode: 52, Score: 3.18, Max: 5.03, Min: 0.62
# Episode: 53, Score: 3.47, Max: 5.62, Min: 1.49
# Episode: 54, Score: 3.72, Max: 5.55, Min: 1.59
# Episode: 55, Score: 3.70, Max: 5.74, Min: 1.71
# Episode: 56, Score: 3.72, Max: 5.56, Min: 2.05
# Episode: 57, Score: 3.48, Max: 8.06, Min: 1.79
# Episode: 58, Score: 3.48, Max: 5.22, Min: 1.09
# Episode: 59, Score: 4.15, Max: 7.91, Min: 2.25
# Episode: 60, Score: 4.62, Max: 8.47, Min: 2.12
# *** Episode 60	Average Score: 1.97, Time: 00:23:58 ***
# Episode: 61, Score: 3.80, Max: 6.17, Min: 2.43
# Episode: 62, Score: 4.27, Max: 6.65, Min: 1.18
# Episode: 63, Score: 4.25, Max: 5.68, Min: 2.88
# Episode: 64, Score: 4.75, Max: 8.64, Min: 1.79
# Episode: 65, Score: 4.27, Max: 6.73, Min: 2.50
# Episode: 66, Score: 4.51, Max: 6.42, Min: 2.86
# Episode: 67, Score: 4.59, Max: 7.24, Min: 2.42
# Episode: 68, Score: 4.55, Max: 7.67, Min: 0.51
# Episode: 69, Score: 4.74, Max: 6.65, Min: 2.99
# Episode: 70, Score: 5.82, Max: 9.36, Min: 0.00
# *** Episode 70	Average Score: 2.34, Time: 00:29:33 ***
# Episode: 71, Score: 5.76, Max: 9.97, Min: 3.98
# Episode: 72, Score: 4.82, Max: 8.13, Min: 2.95
# Episode: 73, Score: 3.92, Max: 6.34, Min: 1.70
# Episode: 74, Score: 4.61, Max: 7.66, Min: 2.91
# Episode: 75, Score: 3.79, Max: 5.11, Min: 2.04
# Episode: 76, Score: 5.18, Max: 9.40, Min: 1.44
# Episode: 77, Score: 5.42, Max: 11.58, Min: 2.68
# Episode: 78, Score: 5.83, Max: 8.10, Min: 3.38
# Episode: 79, Score: 5.76, Max: 9.34, Min: 3.41
# Episode: 80, Score: 4.23, Max: 6.25, Min: 1.29
# *** Episode 80	Average Score: 2.67, Time: 00:35:03 ***
# Episode: 81, Score: 4.95, Max: 6.47, Min: 2.96
# Episode: 82, Score: 5.07, Max: 7.76, Min: 3.32
# Episode: 83, Score: 5.18, Max: 8.84, Min: 2.60
# Episode: 84, Score: 4.31, Max: 7.34, Min: 1.02
# Episode: 85, Score: 4.96, Max: 7.55, Min: 2.73
# Episode: 86, Score: 5.05, Max: 8.46, Min: 1.06
# Episode: 87, Score: 5.59, Max: 8.77, Min: 2.71
# Episode: 88, Score: 5.82, Max: 8.21, Min: 2.49
# Episode: 89, Score: 5.77, Max: 8.88, Min: 2.95
# Episode: 90, Score: 5.38, Max: 6.85, Min: 2.77
# *** Episode 90	Average Score: 2.95, Time: 00:40:28 ***
# Episode: 91, Score: 5.35, Max: 7.43, Min: 3.25
# Episode: 92, Score: 6.02, Max: 13.82, Min: 1.00
# Episode: 93, Score: 5.56, Max: 9.09, Min: 2.59
# Episode: 94, Score: 6.46, Max: 9.08, Min: 3.51
# Episode: 95, Score: 7.36, Max: 16.97, Min: 3.87
# Episode: 96, Score: 7.04, Max: 9.34, Min: 4.33
# Episode: 97, Score: 6.78, Max: 11.13, Min: 4.82
# Episode: 98, Score: 7.03, Max: 13.47, Min: 3.30
# Episode: 99, Score: 5.84, Max: 8.73, Min: 1.42
# Episode: 100, Score: 7.14, Max: 10.99, Min: 3.75
# *** Episode 100	Average Score: 3.30, Time: 00:46:03 ***
# Episode: 101, Score: 8.59, Max: 20.79, Min: 4.84
# Episode: 102, Score: 8.91, Max: 21.35, Min: 5.13
# Episode: 103, Score: 7.62, Max: 10.96, Min: 5.58
# Episode: 104, Score: 7.96, Max: 12.52, Min: 2.21
# Episode: 105, Score: 8.99, Max: 16.58, Min: 4.75
# Episode: 106, Score: 7.52, Max: 11.71, Min: 3.66
# Episode: 107, Score: 7.78, Max: 14.23, Min: 3.31
# Episode: 108, Score: 8.12, Max: 10.81, Min: 4.24
# Episode: 109, Score: 9.81, Max: 14.47, Min: 6.35
# Episode: 110, Score: 7.58, Max: 11.46, Min: 0.41
# *** Episode 110	Average Score: 4.06, Time: 00:51:45 ***
# Episode: 111, Score: 8.50, Max: 13.54, Min: 2.97
# Episode: 112, Score: 9.29, Max: 13.13, Min: 5.86
# Episode: 113, Score: 8.85, Max: 14.19, Min: 5.53
# Episode: 114, Score: 8.13, Max: 12.95, Min: 0.97
# Episode: 115, Score: 9.83, Max: 24.23, Min: 0.35
# Episode: 116, Score: 8.68, Max: 13.09, Min: 3.97
# Episode: 117, Score: 9.88, Max: 16.64, Min: 6.72
# Episode: 118, Score: 9.41, Max: 20.57, Min: 4.00
# Episode: 119, Score: 9.82, Max: 13.00, Min: 2.21
# Episode: 120, Score: 9.91, Max: 15.41, Min: 6.05
# *** Episode 120	Average Score: 4.86, Time: 00:57:33 ***
# Episode: 121, Score: 11.36, Max: 17.28, Min: 5.24
# Episode: 122, Score: 11.23, Max: 17.77, Min: 6.94
# Episode: 123, Score: 12.51, Max: 20.30, Min: 8.19
# Episode: 124, Score: 12.75, Max: 21.98, Min: 6.41
# Episode: 125, Score: 11.90, Max: 15.89, Min: 2.92
# Episode: 126, Score: 12.01, Max: 20.13, Min: 4.13
# Episode: 127, Score: 11.91, Max: 20.45, Min: 3.04
# Episode: 128, Score: 12.80, Max: 16.27, Min: 7.51
# Episode: 129, Score: 12.93, Max: 17.63, Min: 8.30
# Episode: 130, Score: 12.88, Max: 17.64, Min: 6.64
# *** Episode 130	Average Score: 5.90, Time: 01:03:15 ***
# Episode: 131, Score: 16.16, Max: 27.35, Min: 8.30
# Episode: 132, Score: 12.70, Max: 20.63, Min: 5.36
# Episode: 133, Score: 14.55, Max: 21.16, Min: 4.82
# Episode: 134, Score: 15.20, Max: 19.35, Min: 9.33
# Episode: 135, Score: 15.44, Max: 35.99, Min: 0.77
# Episode: 136, Score: 15.80, Max: 26.69, Min: 10.49
# Episode: 137, Score: 16.02, Max: 21.08, Min: 9.08
# Episode: 138, Score: 17.79, Max: 28.19, Min: 10.24
# Episode: 139, Score: 16.90, Max: 22.91, Min: 11.14
# Episode: 140, Score: 17.12, Max: 25.21, Min: 13.48
# *** Episode 140	Average Score: 7.28, Time: 01:09:01 ***
# Episode: 141, Score: 18.09, Max: 22.81, Min: 10.24
# Episode: 142, Score: 19.24, Max: 23.40, Min: 12.43
# Episode: 143, Score: 17.65, Max: 25.40, Min: 11.61
# Episode: 144, Score: 16.67, Max: 24.18, Min: 4.45
# Episode: 145, Score: 18.71, Max: 35.99, Min: 13.88
# Episode: 146, Score: 17.16, Max: 26.42, Min: 11.70
# Episode: 147, Score: 18.12, Max: 22.07, Min: 12.73
# Episode: 148, Score: 20.01, Max: 28.96, Min: 14.46
# Episode: 149, Score: 18.77, Max: 24.09, Min: 13.82
# Episode: 150, Score: 19.92, Max: 32.46, Min: 9.82
# *** Episode 150	Average Score: 8.88, Time: 01:14:50 ***
# Episode: 151, Score: 18.01, Max: 27.00, Min: 9.69
# Episode: 152, Score: 18.04, Max: 22.91, Min: 8.28
# Episode: 153, Score: 20.16, Max: 32.58, Min: 15.11
# Episode: 154, Score: 18.44, Max: 24.51, Min: 12.67
# Episode: 155, Score: 19.19, Max: 26.38, Min: 13.40
# Episode: 156, Score: 19.90, Max: 24.42, Min: 14.62
# Episode: 157, Score: 20.14, Max: 25.71, Min: 14.45
# Episode: 158, Score: 19.83, Max: 25.27, Min: 10.82
# Episode: 159, Score: 21.04, Max: 24.84, Min: 10.85
# Episode: 160, Score: 20.78, Max: 24.48, Min: 12.95
# *** Episode 160	Average Score: 10.47, Time: 01:20:43 ***
# Episode: 161, Score: 20.58, Max: 28.14, Min: 14.24
# Episode: 162, Score: 19.22, Max: 23.38, Min: 10.89
# Episode: 163, Score: 19.83, Max: 25.25, Min: 10.55
# Episode: 164, Score: 20.76, Max: 39.39, Min: 9.62
# Episode: 165, Score: 19.37, Max: 25.09, Min: 9.18
# Episode: 166, Score: 17.05, Max: 27.70, Min: 2.09
# Episode: 167, Score: 18.40, Max: 28.15, Min: 9.86
# Episode: 168, Score: 19.91, Max: 28.59, Min: 9.97
# Episode: 169, Score: 20.20, Max: 26.41, Min: 8.76
# Episode: 170, Score: 20.72, Max: 28.52, Min: 9.17
# *** Episode 170	Average Score: 11.97, Time: 01:26:33 ***
# Episode: 171, Score: 22.55, Max: 27.89, Min: 16.33
# Episode: 172, Score: 21.03, Max: 32.68, Min: 14.06
# Episode: 173, Score: 20.00, Max: 24.77, Min: 6.14
# Episode: 174, Score: 21.64, Max: 34.60, Min: 12.98
# Episode: 175, Score: 24.28, Max: 27.79, Min: 19.67
# Episode: 176, Score: 21.22, Max: 27.69, Min: 11.16
# Episode: 177, Score: 24.00, Max: 29.49, Min: 16.58
# Episode: 178, Score: 22.24, Max: 28.47, Min: 14.90
# Episode: 179, Score: 22.39, Max: 29.11, Min: 8.92
# Episode: 180, Score: 24.80, Max: 39.20, Min: 15.96
# *** Episode 180	Average Score: 13.72, Time: 01:32:10 ***
# Episode: 181, Score: 27.05, Max: 36.25, Min: 22.21
# Episode: 182, Score: 25.11, Max: 31.97, Min: 16.90
# Episode: 183, Score: 25.73, Max: 30.63, Min: 21.78
# Episode: 184, Score: 25.52, Max: 29.80, Min: 17.12
# Episode: 185, Score: 25.58, Max: 30.37, Min: 9.19
# Episode: 186, Score: 25.66, Max: 30.05, Min: 13.15
# Episode: 187, Score: 27.11, Max: 32.20, Min: 19.01
# Episode: 188, Score: 27.63, Max: 33.00, Min: 17.33
# Episode: 189, Score: 28.24, Max: 32.30, Min: 21.44
# Episode: 190, Score: 27.28, Max: 31.21, Min: 20.69
# *** Episode 190	Average Score: 15.85, Time: 01:37:50 ***
# Episode: 191, Score: 27.66, Max: 32.43, Min: 13.78
# Episode: 192, Score: 27.04, Max: 37.82, Min: 11.99
# Episode: 193, Score: 27.22, Max: 31.91, Min: 20.96
# Episode: 194, Score: 27.29, Max: 34.90, Min: 12.48
# Episode: 195, Score: 29.04, Max: 37.69, Min: 23.53
# Episode: 196, Score: 29.54, Max: 35.92, Min: 18.58
# Episode: 197, Score: 29.42, Max: 33.05, Min: 27.57
# Episode: 198, Score: 27.41, Max: 31.81, Min: 20.19
# Episode: 199, Score: 28.71, Max: 32.45, Min: 17.75
# Episode: 200, Score: 28.90, Max: 33.16, Min: 20.60
# *** Episode 200	Average Score: 18.02, Time: 01:43:31 ***
# Episode: 201, Score: 30.19, Max: 34.16, Min: 23.08
# Episode: 202, Score: 30.24, Max: 33.88, Min: 25.07
# Episode: 203, Score: 30.10, Max: 36.73, Min: 23.66
# Episode: 204, Score: 29.37, Max: 32.95, Min: 24.56
# Episode: 205, Score: 30.81, Max: 35.90, Min: 23.57
# Episode: 206, Score: 30.66, Max: 35.01, Min: 24.10
# Episode: 207, Score: 29.15, Max: 35.45, Min: 23.69
# Episode: 208, Score: 29.29, Max: 35.26, Min: 24.21
# Episode: 209, Score: 29.87, Max: 33.52, Min: 23.83
# Episode: 210, Score: 28.60, Max: 33.34, Min: 24.69
# *** Episode 210	Average Score: 20.18, Time: 01:49:28 ***
# Episode: 211, Score: 29.25, Max: 34.16, Min: 26.17
# Episode: 212, Score: 31.18, Max: 37.14, Min: 24.66
# Episode: 213, Score: 30.54, Max: 36.90, Min: 22.32
# Episode: 214, Score: 32.00, Max: 39.20, Min: 26.24
# Episode: 215, Score: 32.18, Max: 37.14, Min: 27.83
# Episode: 216, Score: 32.04, Max: 37.70, Min: 20.71
# Episode: 217, Score: 32.92, Max: 36.29, Min: 25.25
# Episode: 218, Score: 31.01, Max: 38.93, Min: 23.82
# Episode: 219, Score: 33.91, Max: 38.24, Min: 29.92
# Episode: 220, Score: 32.45, Max: 37.71, Min: 22.85
# *** Episode 220	Average Score: 22.43, Time: 01:55:23 ***
# Episode: 221, Score: 34.88, Max: 38.60, Min: 27.74
# Episode: 222, Score: 34.73, Max: 39.61, Min: 25.78
# Episode: 223, Score: 34.22, Max: 38.14, Min: 29.21
# Episode: 224, Score: 34.69, Max: 39.46, Min: 29.65
# Episode: 225, Score: 34.61, Max: 38.09, Min: 27.00
# Episode: 226, Score: 32.85, Max: 37.10, Min: 23.64
# Episode: 227, Score: 33.60, Max: 38.09, Min: 24.68
# Episode: 228, Score: 34.63, Max: 38.34, Min: 29.94
# Episode: 229, Score: 32.79, Max: 39.19, Min: 21.56
# Episode: 230, Score: 33.29, Max: 38.93, Min: 20.27
# *** Episode 230	Average Score: 24.61, Time: 02:01:07 ***
# Episode: 231, Score: 35.81, Max: 38.61, Min: 30.26
# Episode: 232, Score: 35.98, Max: 39.01, Min: 32.94
# Episode: 233, Score: 33.68, Max: 37.99, Min: 24.24
# Episode: 234, Score: 34.52, Max: 37.97, Min: 27.62
# Episode: 235, Score: 35.24, Max: 38.44, Min: 28.94
# Episode: 236, Score: 36.48, Max: 39.49, Min: 21.85
# Episode: 237, Score: 34.03, Max: 37.92, Min: 30.40
# Episode: 238, Score: 35.62, Max: 38.94, Min: 31.34
# Episode: 239, Score: 33.94, Max: 37.45, Min: 28.66
# Episode: 240, Score: 36.93, Max: 39.50, Min: 32.73
# *** Episode 240	Average Score: 26.56, Time: 02:06:50 ***
# Episode: 241, Score: 36.23, Max: 39.17, Min: 32.53
# Episode: 242, Score: 36.09, Max: 39.42, Min: 30.49
# Episode: 243, Score: 36.54, Max: 39.31, Min: 33.00
# Episode: 244, Score: 35.55, Max: 39.43, Min: 29.88
# Episode: 245, Score: 35.46, Max: 38.18, Min: 31.84
# Episode: 246, Score: 35.65, Max: 38.46, Min: 31.34
# Episode: 247, Score: 35.83, Max: 38.48, Min: 31.03
# Episode: 248, Score: 36.61, Max: 39.13, Min: 29.17
# Episode: 249, Score: 36.20, Max: 38.72, Min: 31.98
# Episode: 250, Score: 35.81, Max: 39.21, Min: 31.52
# *** Episode 250	Average Score: 28.31, Time: 02:12:40 ***
# Episode: 251, Score: 36.21, Max: 39.34, Min: 31.93
# Episode: 252, Score: 35.47, Max: 39.65, Min: 29.35
# Episode: 253, Score: 35.19, Max: 39.35, Min: 18.43
# Episode: 254, Score: 36.40, Max: 39.39, Min: 27.32
# Episode: 255, Score: 36.53, Max: 39.64, Min: 26.22
# Episode: 256, Score: 36.65, Max: 39.41, Min: 33.42
# Episode: 257, Score: 35.99, Max: 39.63, Min: 31.58
# Episode: 258, Score: 36.46, Max: 39.19, Min: 28.50
# Episode: 259, Score: 35.59, Max: 38.39, Min: 30.14
# Episode: 260, Score: 35.51, Max: 39.48, Min: 27.71
# *** Episode 260	Average Score: 29.96, Time: 02:18:40 ***
# Episode: 261, Score: 35.90, Max: 39.39, Min: 28.82
# *** Episode 261	Average Score: 30.11, Time: 02:19:15 ***
# Environment solved !

# %%
import matplotlib.pyplot as plt

plt.xlabel('episodes')
plt.ylabel('scores')
plt.plot(scores)
# plt.show()
plt.savefig('plot.png')

# %%
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8)
agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = agent.act(states) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 17.7689996028319
